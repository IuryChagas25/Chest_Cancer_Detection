# %%
import os                                             # Operational System para manipulação de arquivos.
import cv2                                            # OpenCV para manipulação de imagens.
import random
import numpy as np                                    # Numpy para manipulação de matrizes e arrays.
import matplotlib.pyplot as plt                       # Pyplot para plotagem de gráficos e imagens.
from sklearn.metrics import confusion_matrix          # Scikit-Learn para plotar a matriz de confusão
import seaborn as sn
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers                   # Módulo de camadas do Keras
from tensorflow.keras import callbacks                # Módulo de callbacks do Keras
from tensorflow.keras import optimizers               # Módulo de otimizadores do Keras
from tensorflow.keras.models import load_model        # Função para carregar um modelo salvo
from tensorflow.keras.models import Sequential        # Classe de modelos sequenciais para construir as redes neurais.
from tensorflow.keras.applications import VGG16       # Rede pre treinada (VGG16)

from google_drive_downloader import GoogleDriveDownloader as gdd

# ImageDataGenerator, utilizado para carregar imagens em tempo de execução
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# drive  sample_data

# %%
val_datagen   = ImageDataGenerator( rescale = 1./255 )
val_generator = val_datagen.flow_from_directory("/content/drive/MyDrive/Chest Cancer Detection Resized/Data/validation resized", target_size = (250, 250),
                                                 batch_size  = 64)
# Out:
# Found 72 images belonging to 4 classes.

# %%
# Atributo do generator que fornece o número de amostras detectadas
val_samples = val_generator.samples 
print(val_samples, "amostras detectadas")

# Atributo do generator que fornece o mapeamento de classe para índice 
# Repare que os índices são definidos pelo generator com base nos diretórios de arquivos em ordem alfabética
class_to_idx_dict = val_generator.class_indices
print( "Mapeamento Classes -> Índices:", class_to_idx_dict )

# Construção de um novo dicionário que inverte o mapeamento
idx_to_class_dict = { v: k for k, v in class_to_idx_dict.items() }
print( "Mapeamento Índices -> Classes:", idx_to_class_dict )
# Out:
# 72 amostras detectadas
# Mapeamento Classes -> Índices: {'Resized adenocarcinoma': 0, 'Resized large.cell.carcinoma': 1, 'Resized normal': 2, 'Resized squamous.cell.carcinoma': 3}
# Mapeamento Índices -> Classes: {0: 'Resized adenocarcinoma', 1: 'Resized large.cell.carcinoma', 2: 'Resized normal', 3: 'Resized squamous.cell.carcinoma'}

# %%
train_datagen = ImageDataGenerator(
    rescale = 1. / 255,        # normalizando as imagens
    rotation_range = 20,       # Rotação aleatória de até 20°
    width_shift_range = 0.2,   # Translação horizontal de até 20% da largura
    height_shift_range = 0.2,  # Translação vertical de até 20% da altura
    #zoom_range = 0.2,          # Zoom aleatório de até 20%
    shear_range = 0.1,         # Deformação de 10%
    horizontal_flip = True,    # Espelhamento horizontal aleatório
    vertical_flip = False,     # Espelhamento vertical aleatório
    fill_mode = "nearest")     # Preenchimentod e buracos pelo pixel mais próximo

train_generator = train_datagen.flow_from_directory(
    "/content/drive/MyDrive/Chest Cancer Detection Resized/Data/train resized", target_size = (250, 250),
    batch_size  = 64)


# Atributo do generator que fornece o número de amostras detectadas
train_samples = train_generator.samples 
print(train_samples)
# Out:
# Found 601 images belonging to 4 classes.
# 601

# %%
test_datagen   = ImageDataGenerator( rescale = 1./255 )
test_generator = test_datagen.flow_from_directory("/content/drive/MyDrive/Chest Cancer Detection Resized/Data/test resized", target_size = (250, 250),
                                                   batch_size  = 64, shuffle = False)
batch_size = 64
# Out:
# Found 315 images belonging to 4 classes.

# %%
def print_vgg16_summary( shape ):
    conv_base = VGG16(include_top = False, weights = "imagenet", input_shape = shape)
    print( conv_base.summary() )
    return

print_vgg16_summary( shape = (250, 250, 3) )
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 250, 250, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 250, 250, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 250, 250, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 125, 125, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 125, 125, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 125, 125, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 62, 62, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 62, 62, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 62, 62, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 62, 62, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 31, 31, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 31, 31, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 31, 31, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 15, 15, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 15, 15, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
def build_model( input_shape, n_outputs ):
    # Base convolucional
    conv_base = VGG16(include_top = False, weights = "imagenet", input_shape = input_shape)
    conv_base.trainable = False
    
    rede = Sequential()
    rede.add( conv_base )
    rede.add( layers.Flatten() )
    rede.add( layers.Dense( 256, activation = "relu" ) )
    rede.add( layers.Dense(   4, activation = "softmax" ) )
    
    return rede

model = build_model( (250, 250, 3), 1 )
model.compile(optimizer=optimizers.Adam(lr=1e-4), 
              loss="categorical_crossentropy", 
              metrics=["acc"])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 21,138,500
# Trainable params: 6,423,812
# Non-trainable params: 14,714,688
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
conv_base = model.get_layer("vgg16")
for layer in conv_base.layers:
    status = "Treinável" if layer.trainable else "Congelada"
    print("Camada '{}' - Status: {} - Entrada: {} - Saída: {}".format(layer.name,
                                                                      status, 
                                                                      layer.input_shape, 
                                                                      layer.output_shape))
# Out:
# Camada 'input_4' - Status: Congelada - Entrada: [(None, 250, 250, 3)] - Saída: [(None, 250, 250, 3)]
# Camada 'block1_conv1' - Status: Congelada - Entrada: (None, 250, 250, 3) - Saída: (None, 250, 250, 64)
# Camada 'block1_conv2' - Status: Congelada - Entrada: (None, 250, 250, 64) - Saída: (None, 250, 250, 64)
# Camada 'block1_pool' - Status: Congelada - Entrada: (None, 250, 250, 64) - Saída: (None, 125, 125, 64)
# Camada 'block2_conv1' - Status: Congelada - Entrada: (None, 125, 125, 64) - Saída: (None, 125, 125, 128)
# Camada 'block2_conv2' - Status: Congelada - Entrada: (None, 125, 125, 128) - Saída: (None, 125, 125, 128)
# Camada 'block2_pool' - Status: Congelada - Entrada: (None, 125, 125, 128) - Saída: (None, 62, 62, 128)
# Camada 'block3_conv1' - Status: Congelada - Entrada: (None, 62, 62, 128) - Saída: (None, 62, 62, 256)
# Camada 'block3_conv2' - Status: Congelada - Entrada: (None, 62, 62, 256) - Saída: (None, 62, 62, 256)
# Camada 'block3_conv3' - Status: Congelada - Entrada: (None, 62, 62, 256) - Saída: (None, 62, 62, 256)
# Camada 'block3_pool' - Status: Congelada - Entrada: (None, 62, 62, 256) - Saída: (None, 31, 31, 256)
# Camada 'block4_conv1' - Status: Congelada - Entrada: (None, 31, 31, 256) - Saída: (None, 31, 31, 512)
# Camada 'block4_conv2' - Status: Congelada - Entrada: (None, 31, 31, 512) - Saída: (None, 31, 31, 512)
# Camada 'block4_conv3' - Status: Congelada - Entrada: (None, 31, 31, 512) - Saída: (None, 31, 31, 512)
# Camada 'block4_pool' - Status: Congelada - Entrada: (None, 31, 31, 512) - Saída: (None, 15, 15, 512)
# Camada 'block5_conv1' - Status: Congelada - Entrada: (None, 15, 15, 512) - Saída: (None, 15, 15, 512)
# Camada 'block5_conv2' - Status: Congelada - Entrada: (None, 15, 15, 512) - Saída: (None, 15, 15, 512)
# Camada 'block5_conv3' - Status: Congelada - Entrada: (None, 15, 15, 512) - Saída: (None, 15, 15, 512)
# Camada 'block5_pool' - Status: Congelada - Entrada: (None, 15, 15, 512) - Saída: (None, 7, 7, 512)

# %%
model.compile(optimizer=optimizers.Adam(learning_rate = 1e-5), 
              loss = "categorical_crossentropy", 
              metrics = ["acc"])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_2 (Dense)             (None, 256)               6422784
#
#  dense_3 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 21,138,500
# Trainable params: 6,423,812
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
ACCURACY_THRESHOLD = 0.95

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
      if(logs.get('val_accuracy') > ACCURACY_THRESHOLD):
          print("\nReached %2.2f%% accuracy, so stopping training!!" %(ACCURACY_THRESHOLD*100))
          model.save("model2.h5")
          self.model.stop_training = True

METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'),  
      tf.keras.metrics.AUC(name='auc')
]
callbacks = myCallback()
model.compile(optimizer=optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy',metrics=METRICS)

# %%
history=model.fit(train_generator,validation_data=val_generator,epochs = 1000,callbacks=[callbacks],verbose = 1)
# Out:
# Epoch 1/1000
# 10/10 [==============================] - 17s 2s/step - loss: 5.5947 - accuracy: 0.7047 - precision: 0.4014 - recall: 0.3694 - auc: 0.6072 - val_loss: 1.6281 - val_accuracy: 0.7049 - val_precision: 0.3968 - val_recall: 0.3472 - val_auc: 0.6886
# Epoch 2/1000
# 10/10 [==============================] - 14s 1s/step - loss: 1.5121 - accuracy: 0.7296 - precision: 0.4522 - recall: 0.3860 - auc: 0.7075 - val_loss: 1.0945 - val_accuracy: 0.7569 - val_precision: 0.5152 - val_recall: 0.4722 - val_auc: 0.7906
# Epoch 3/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.9493 - accuracy: 0.7999 - precision: 0.6316 - recall: 0.4792 - auc: 0.8356 - val_loss: 0.9355 - val_accuracy: 0.7882 - val_precision: 0.7037 - val_recall: 0.2639 - val_auc: 0.8130
# Epoch 4/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.8520 - accuracy: 0.8195 - precision: 0.7685 - recall: 0.3977 - auc: 0.8652 - val_loss: 0.9999 - val_accuracy: 0.7778 - val_precision: 0.6053 - val_recall: 0.3194 - val_auc: 0.7859
# Epoch 5/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.8250 - accuracy: 0.8203 - precision: 0.7150 - recall: 0.4676 - auc: 0.8701 - val_loss: 0.9211 - val_accuracy: 0.7882 - val_precision: 0.6571 - val_recall: 0.3194 - val_auc: 0.8299
# Epoch 6/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.7335 - accuracy: 0.8478 - precision: 0.8036 - recall: 0.5175 - auc: 0.9094 - val_loss: 0.8886 - val_accuracy: 0.8021 - val_precision: 0.6829 - val_recall: 0.3889 - val_auc: 0.8411
# Epoch 7/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.7510 - accuracy: 0.8357 - precision: 0.7320 - recall: 0.5408 - auc: 0.8966 - val_loss: 0.8370 - val_accuracy: 0.8229 - val_precision: 0.7692 - val_recall: 0.4167 - val_auc: 0.8668
# Epoch 8/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.7295 - accuracy: 0.8494 - precision: 0.8329 - recall: 0.4975 - auc: 0.9131 - val_loss: 0.8832 - val_accuracy: 0.7743 - val_precision: 0.5660 - val_recall: 0.4167 - val_auc: 0.8581
# Epoch 9/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.7396 - accuracy: 0.8436 - precision: 0.7368 - recall: 0.5824 - auc: 0.8984 - val_loss: 0.8346 - val_accuracy: 0.7951 - val_precision: 0.6275 - val_recall: 0.4444 - val_auc: 0.8677
# Epoch 10/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.6855 - accuracy: 0.8532 - precision: 0.7818 - recall: 0.5724 - auc: 0.9161 - val_loss: 0.7771 - val_accuracy: 0.8472 - val_precision: 0.9118 - val_recall: 0.4306 - val_auc: 0.9122
# Epoch 11/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.6787 - accuracy: 0.8544 - precision: 0.7846 - recall: 0.5757 - auc: 0.9168 - val_loss: 0.9257 - val_accuracy: 0.7882 - val_precision: 0.6078 - val_recall: 0.4306 - val_auc: 0.8390
# Epoch 12/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.6474 - accuracy: 0.8640 - precision: 0.7819 - recall: 0.6323 - auc: 0.9249 - val_loss: 0.9209 - val_accuracy: 0.8125 - val_precision: 0.7045 - val_recall: 0.4306 - val_auc: 0.8501
# Epoch 13/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.5866 - accuracy: 0.8781 - precision: 0.8222 - recall: 0.6539 - auc: 0.9442 - val_loss: 0.7468 - val_accuracy: 0.8576 - val_precision: 0.8780 - val_recall: 0.5000 - val_auc: 0.9164
# Epoch 14/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.5783 - accuracy: 0.8819 - precision: 0.8468 - recall: 0.6439 - auc: 0.9450 - val_loss: 0.7781 - val_accuracy: 0.8368 - val_precision: 0.7193 - val_recall: 0.5694 - val_auc: 0.8931
# Epoch 15/1000
# 10/10 [==============================] - 15s 2s/step - loss: 0.5559 - accuracy: 0.8977 - precision: 0.8660 - recall: 0.6988 - auc: 0.9543 - val_loss: 0.7572 - val_accuracy: 0.8611 - val_precision: 0.8200 - val_recall: 0.5694 - val_auc: 0.9012
# Epoch 16/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.5584 - accuracy: 0.8943 - precision: 0.8577 - recall: 0.6922 - auc: 0.9509 - val_loss: 0.8485 - val_accuracy: 0.8507 - val_precision: 0.7736 - val_recall: 0.5694 - val_auc: 0.8843
# Epoch 17/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.5130 - accuracy: 0.9072 - precision: 0.8750 - recall: 0.7338 - auc: 0.9596 - val_loss: 0.7179 - val_accuracy: 0.8681 - val_precision: 0.8148 - val_recall: 0.6111 - val_auc: 0.9169
# Epoch 18/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4830 - accuracy: 0.9122 - precision: 0.8809 - recall: 0.7504 - auc: 0.9678 - val_loss: 0.7079 - val_accuracy: 0.8681 - val_precision: 0.7833 - val_recall: 0.6528 - val_auc: 0.9143
# Epoch 19/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4563 - accuracy: 0.9147 - precision: 0.8779 - recall: 0.7654 - auc: 0.9689 - val_loss: 0.6667 - val_accuracy: 0.8507 - val_precision: 0.7377 - val_recall: 0.6250 - val_auc: 0.9201
# Epoch 20/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4446 - accuracy: 0.9218 - precision: 0.8889 - recall: 0.7854 - auc: 0.9703 - val_loss: 0.6571 - val_accuracy: 0.8611 - val_precision: 0.7667 - val_recall: 0.6389 - val_auc: 0.9254
# Epoch 21/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4123 - accuracy: 0.9309 - precision: 0.9143 - recall: 0.7987 - auc: 0.9783 - val_loss: 0.6371 - val_accuracy: 0.8854 - val_precision: 0.8197 - val_recall: 0.6944 - val_auc: 0.9343
# Epoch 22/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4038 - accuracy: 0.9330 - precision: 0.9135 - recall: 0.8087 - auc: 0.9787 - val_loss: 0.6494 - val_accuracy: 0.8646 - val_precision: 0.7797 - val_recall: 0.6389 - val_auc: 0.9288
# Epoch 23/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.4224 - accuracy: 0.9164 - precision: 0.8663 - recall: 0.7870 - auc: 0.9708 - val_loss: 0.6690 - val_accuracy: 0.9028 - val_precision: 0.8438 - val_recall: 0.7500 - val_auc: 0.9270
# Epoch 24/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3762 - accuracy: 0.9351 - precision: 0.9128 - recall: 0.8186 - auc: 0.9803 - val_loss: 0.6135 - val_accuracy: 0.9062 - val_precision: 0.8571 - val_recall: 0.7500 - val_auc: 0.9410
# Epoch 25/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3543 - accuracy: 0.9359 - precision: 0.9162 - recall: 0.8186 - auc: 0.9831 - val_loss: 0.6394 - val_accuracy: 0.9167 - val_precision: 0.8529 - val_recall: 0.8056 - val_auc: 0.9324
# Epoch 26/1000
# 10/10 [==============================] - 15s 2s/step - loss: 0.3597 - accuracy: 0.9364 - precision: 0.9014 - recall: 0.8369 - auc: 0.9809 - val_loss: 0.6970 - val_accuracy: 0.8993 - val_precision: 0.8209 - val_recall: 0.7639 - val_auc: 0.9180
# Epoch 27/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3416 - accuracy: 0.9426 - precision: 0.9112 - recall: 0.8536 - auc: 0.9833 - val_loss: 0.6078 - val_accuracy: 0.9097 - val_precision: 0.8594 - val_recall: 0.7639 - val_auc: 0.9437
# Epoch 28/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3153 - accuracy: 0.9509 - precision: 0.9320 - recall: 0.8669 - auc: 0.9877 - val_loss: 0.5968 - val_accuracy: 0.8958 - val_precision: 0.8182 - val_recall: 0.7500 - val_auc: 0.9385
# Epoch 29/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3810 - accuracy: 0.9309 - precision: 0.8877 - recall: 0.8286 - auc: 0.9764 - val_loss: 0.6347 - val_accuracy: 0.9132 - val_precision: 0.8615 - val_recall: 0.7778 - val_auc: 0.9349
# Epoch 30/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3380 - accuracy: 0.9401 - precision: 0.9088 - recall: 0.8453 - auc: 0.9835 - val_loss: 0.5486 - val_accuracy: 0.9236 - val_precision: 0.8788 - val_recall: 0.8056 - val_auc: 0.9492
# Epoch 31/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3918 - accuracy: 0.9314 - precision: 0.8825 - recall: 0.8369 - auc: 0.9729 - val_loss: 0.6981 - val_accuracy: 0.9028 - val_precision: 0.8235 - val_recall: 0.7778 - val_auc: 0.9248
# Epoch 32/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3070 - accuracy: 0.9476 - precision: 0.9145 - recall: 0.8719 - auc: 0.9857 - val_loss: 0.6981 - val_accuracy: 0.8958 - val_precision: 0.8088 - val_recall: 0.7639 - val_auc: 0.9277
# Epoch 33/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3050 - accuracy: 0.9468 - precision: 0.9142 - recall: 0.8686 - auc: 0.9851 - val_loss: 0.6548 - val_accuracy: 0.9028 - val_precision: 0.8438 - val_recall: 0.7500 - val_auc: 0.9339
# Epoch 34/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.3127 - accuracy: 0.9430 - precision: 0.9014 - recall: 0.8669 - auc: 0.9845 - val_loss: 0.6145 - val_accuracy: 0.9201 - val_precision: 0.8769 - val_recall: 0.7917 - val_auc: 0.9407
# Epoch 35/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2961 - accuracy: 0.9501 - precision: 0.9168 - recall: 0.8802 - auc: 0.9866 - val_loss: 0.6587 - val_accuracy: 0.9028 - val_precision: 0.8235 - val_recall: 0.7778 - val_auc: 0.9355
# Epoch 36/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2913 - accuracy: 0.9451 - precision: 0.9064 - recall: 0.8702 - auc: 0.9864 - val_loss: 0.5814 - val_accuracy: 0.9236 - val_precision: 0.8571 - val_recall: 0.8333 - val_auc: 0.9449
# Epoch 37/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2994 - accuracy: 0.9418 - precision: 0.9023 - recall: 0.8602 - auc: 0.9850 - val_loss: 0.6366 - val_accuracy: 0.9167 - val_precision: 0.8429 - val_recall: 0.8194 - val_auc: 0.9365
# Epoch 38/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2927 - accuracy: 0.9405 - precision: 0.8990 - recall: 0.8586 - auc: 0.9857 - val_loss: 0.5307 - val_accuracy: 0.9375 - val_precision: 0.8857 - val_recall: 0.8611 - val_auc: 0.9541
# Epoch 39/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2936 - accuracy: 0.9459 - precision: 0.9096 - recall: 0.8702 - auc: 0.9857 - val_loss: 0.5650 - val_accuracy: 0.9236 - val_precision: 0.8676 - val_recall: 0.8194 - val_auc: 0.9460
# Epoch 40/1000
# 10/10 [==============================] - 14s 2s/step - loss: 0.2627 - accuracy: 0.9472 - precision: 0.9115 - recall: 0.8735 - auc: 0.9884 - val_loss: 0.6125 - val_accuracy: 0.9167 - val_precision: 0.8529 - val_recall: 0.8056 - val_auc: 0.9432
# Epoch 41/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2589 - accuracy: 0.9526 - precision: 0.9177 - recall: 0.8902 - auc: 0.9893 - val_loss: 0.6148 - val_accuracy: 0.9097 - val_precision: 0.8485 - val_recall: 0.7778 - val_auc: 0.9439
# Epoch 42/1000
# 10/10 [==============================] - 15s 2s/step - loss: 0.2623 - accuracy: 0.9530 - precision: 0.9266 - recall: 0.8819 - auc: 0.9888 - val_loss: 0.5277 - val_accuracy: 0.9306 - val_precision: 0.8714 - val_recall: 0.8472 - val_auc: 0.9561
# Epoch 43/1000
# 10/10 [==============================] - 14s 2s/step - loss: 0.2248 - accuracy: 0.9651 - precision: 0.9419 - recall: 0.9168 - auc: 0.9926 - val_loss: 0.5355 - val_accuracy: 0.9306 - val_precision: 0.8824 - val_recall: 0.8333 - val_auc: 0.9545
# Epoch 44/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2196 - accuracy: 0.9580 - precision: 0.9296 - recall: 0.9002 - auc: 0.9931 - val_loss: 0.6085 - val_accuracy: 0.9271 - val_precision: 0.8696 - val_recall: 0.8333 - val_auc: 0.9509
# Epoch 45/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.2366 - accuracy: 0.9609 - precision: 0.9363 - recall: 0.9052 - auc: 0.9906 - val_loss: 0.5918 - val_accuracy: 0.9028 - val_precision: 0.8143 - val_recall: 0.7917 - val_auc: 0.9472
# Epoch 46/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2588 - accuracy: 0.9484 - precision: 0.9162 - recall: 0.8735 - auc: 0.9889 - val_loss: 0.5915 - val_accuracy: 0.9340 - val_precision: 0.8841 - val_recall: 0.8472 - val_auc: 0.9488
# Epoch 47/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2311 - accuracy: 0.9601 - precision: 0.9407 - recall: 0.8968 - auc: 0.9916 - val_loss: 0.5101 - val_accuracy: 0.9340 - val_precision: 0.8732 - val_recall: 0.8611 - val_auc: 0.9572
# Epoch 48/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2514 - accuracy: 0.9526 - precision: 0.9177 - recall: 0.8902 - auc: 0.9891 - val_loss: 0.5120 - val_accuracy: 0.9306 - val_precision: 0.8714 - val_recall: 0.8472 - val_auc: 0.9544
# Epoch 49/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2038 - accuracy: 0.9684 - precision: 0.9487 - recall: 0.9235 - auc: 0.9939 - val_loss: 0.5468 - val_accuracy: 0.9201 - val_precision: 0.8551 - val_recall: 0.8194 - val_auc: 0.9535
# Epoch 50/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2088 - accuracy: 0.9688 - precision: 0.9488 - recall: 0.9251 - auc: 0.9929 - val_loss: 0.5589 - val_accuracy: 0.9375 - val_precision: 0.8857 - val_recall: 0.8611 - val_auc: 0.9541
# Epoch 51/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2289 - accuracy: 0.9542 - precision: 0.9168 - recall: 0.8985 - auc: 0.9911 - val_loss: 0.4953 - val_accuracy: 0.9410 - val_precision: 0.8873 - val_recall: 0.8750 - val_auc: 0.9589
# Epoch 52/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2154 - accuracy: 0.9634 - precision: 0.9325 - recall: 0.9201 - auc: 0.9913 - val_loss: 0.5022 - val_accuracy: 0.9375 - val_precision: 0.8857 - val_recall: 0.8611 - val_auc: 0.9590
# Epoch 53/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2442 - accuracy: 0.9522 - precision: 0.9161 - recall: 0.8902 - auc: 0.9899 - val_loss: 0.5465 - val_accuracy: 0.9236 - val_precision: 0.8472 - val_recall: 0.8472 - val_auc: 0.9574
# Epoch 54/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2141 - accuracy: 0.9609 - precision: 0.9304 - recall: 0.9118 - auc: 0.9920 - val_loss: 0.4950 - val_accuracy: 0.9375 - val_precision: 0.8750 - val_recall: 0.8750 - val_auc: 0.9593
# Epoch 55/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.2012 - accuracy: 0.9597 - precision: 0.9257 - recall: 0.9118 - auc: 0.9935 - val_loss: 0.5441 - val_accuracy: 0.9306 - val_precision: 0.8714 - val_recall: 0.8472 - val_auc: 0.9560
# Epoch 56/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1614 - accuracy: 0.9746 - precision: 0.9561 - recall: 0.9418 - auc: 0.9960 - val_loss: 0.4965 - val_accuracy: 0.9410 - val_precision: 0.8986 - val_recall: 0.8611 - val_auc: 0.9638
# Epoch 57/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1573 - accuracy: 0.9713 - precision: 0.9493 - recall: 0.9351 - auc: 0.9966 - val_loss: 0.5474 - val_accuracy: 0.9306 - val_precision: 0.8714 - val_recall: 0.8472 - val_auc: 0.9569
# Epoch 58/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1758 - accuracy: 0.9734 - precision: 0.9528 - recall: 0.9401 - auc: 0.9947 - val_loss: 0.6027 - val_accuracy: 0.9236 - val_precision: 0.8571 - val_recall: 0.8333 - val_auc: 0.9472
# Epoch 59/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1758 - accuracy: 0.9688 - precision: 0.9488 - recall: 0.9251 - auc: 0.9953 - val_loss: 0.6816 - val_accuracy: 0.9167 - val_precision: 0.8333 - val_recall: 0.8333 - val_auc: 0.9389
# Epoch 60/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1707 - accuracy: 0.9700 - precision: 0.9460 - recall: 0.9334 - auc: 0.9957 - val_loss: 0.5865 - val_accuracy: 0.9236 - val_precision: 0.8472 - val_recall: 0.8472 - val_auc: 0.9503
# Epoch 61/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1821 - accuracy: 0.9680 - precision: 0.9426 - recall: 0.9285 - auc: 0.9944 - val_loss: 0.5645 - val_accuracy: 0.9410 - val_precision: 0.8986 - val_recall: 0.8611 - val_auc: 0.9502
# Epoch 62/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1633 - accuracy: 0.9746 - precision: 0.9561 - recall: 0.9418 - auc: 0.9955 - val_loss: 0.5500 - val_accuracy: 0.9306 - val_precision: 0.8611 - val_recall: 0.8611 - val_auc: 0.9553
# Epoch 63/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1657 - accuracy: 0.9763 - precision: 0.9595 - recall: 0.9451 - auc: 0.9955 - val_loss: 0.6203 - val_accuracy: 0.9340 - val_precision: 0.8841 - val_recall: 0.8472 - val_auc: 0.9455
# Epoch 64/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1457 - accuracy: 0.9734 - precision: 0.9543 - recall: 0.9384 - auc: 0.9970 - val_loss: 0.5030 - val_accuracy: 0.9479 - val_precision: 0.9014 - val_recall: 0.8889 - val_auc: 0.9611
# Epoch 65/1000
# 10/10 [==============================] - 14s 1s/step - loss: 0.1454 - accuracy: 0.9767 - precision: 0.9580 - recall: 0.9484 - auc: 0.9972 - val_loss: 0.5526 - val_accuracy: 0.9375 - val_precision: 0.8857 - val_recall: 0.8611 - val_auc: 0.9539
# Epoch 66/1000
# 10/10 [==============================] - 15s 1s/step - loss: 0.1577 - accuracy: 0.9738 - precision: 0.9513 - recall: 0.9434 - auc: 0.9957 - val_loss: 0.5017 - val_accuracy: 0.9410 - val_precision: 0.8873 - val_recall: 0.8750 - val_auc: 0.9617
# Epoch 67/1000
# 10/10 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9784 - precision: 0.9645 - recall: 0.9484 - auc: 0.9976
# Reached 95.00% accuracy, so stopping training!!
# 10/10 [==============================] - 15s 1s/step - loss: 0.1309 - accuracy: 0.9784 - precision: 0.9645 - recall: 0.9484 - auc: 0.9976 - val_loss: 0.5349 - val_accuracy: 0.9514 - val_precision: 0.9028 - val_recall: 0.9028 - val_auc: 0.9554

# %%
test_datagen   = ImageDataGenerator( rescale = 1./255 )
test_generator = test_datagen.flow_from_directory("/content/drive/MyDrive/Chest Cancer Detection Resized/Data/test resized", target_size = (250, 250),
                                                   batch_size  = 64, shuffle = False)

# Atributo do generator que fornece o número de amostras detectadas
test_samples = test_generator.samples

test_loss, accuracy,_,_,_ = model.evaluate( test_generator )

print("Test Accuracy:", 100*accuracy, "%")
print("Acertos: {} - Erros: {}".format(round(test_samples * accuracy), 
                                       round(test_samples * (1-accuracy) )))
# Out:
# Found 315 images belonging to 4 classes.
# 5/5 [==============================] - 38s 9s/step - loss: 0.3041 - accuracy: 0.9373 - precision: 0.8806 - recall: 0.8667 - auc: 0.9816
# Test Accuracy: 93.73015761375427 %
# Acertos: 295 - Erros: 20

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['loss'])
plt.title('Precisão de Modelo')
plt.ylabel('Precisão')
plt.xlabel('Tempo')
plt.legend(['Acuracia', 'Loss'], loc = 0)
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Precisão de Modelo')
plt.ylabel('Precisão')
plt.xlabel('Tempo')
plt.legend(['Acuracia', 'validação'], loc = 0)
plt.show()

# %%
fig, axes = plt.subplots(1, 2, squeeze = False, figsize = (16,8))

# Loss
train_loss_values = history.history["loss"]
val_loss_values = history.history["val_loss"]

# Epochs
epochs = range(1, len(train_loss_values) + 1)

# Accuracy
train_acc_values = history.history["accuracy"]
val_acc_values = history.history["val_accuracy"]

ax = axes.flat[0]
ax.plot(epochs, train_loss_values, "r", label="Training loss")
ax.plot(epochs, val_loss_values, "b", label="Validation loss")
ax.set_title("Training and validation Loss")
ax.set_xlabel("Epochs")
ax.set_ylabel("Loss")
ax.legend()

ax = axes.flat[1]
ax.plot(epochs, train_acc_values, "r", label="Training acc")
ax.plot(epochs, val_acc_values, "b", label="Validation acc")
ax.set_title("Training and validation Accuracy")
ax.set_xlabel("Epochs")
ax.set_ylabel("Accuracy")
ax.legend()

# %%
# obtendo os dados do gerador de imagens
x1, y1 = test_generator[1]
x2, y2 = test_generator[2]
x3, y3 = test_generator[3]

# concatenando os dados obtidos do gerados
x = np.concatenate((x1, x2, x3))
y = np.concatenate((y1, y2, y3))

# %%
# realizando a predição com os dados de teste
predict_y = model.predict(x)

# %%
# plotando a matriz de confusão
label_encoder = ['adenocarcinoma', 'large.cell.carcinoma', 'normal', 'squamous.cell.carcinoma']
confusion_ma = confusion_matrix(np.argmax(y, axis = 1), np.argmax(predict_y, axis=1))
df_cm = pd.DataFrame(confusion_ma, index = [i for i in label_encoder],
                     columns = [i for i in label_encoder])
plt.figure(figsize = (20,14))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True, annot_kws={"size": 20})
plt.title('Matriz de Confusão', size = 30)
# Out:
# Text(0.5, 1.0, 'Matriz de Confusão')
